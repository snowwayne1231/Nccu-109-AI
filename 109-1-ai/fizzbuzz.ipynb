# %%
#載入套件
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.optimizers import RMSprop
from keras.utils import np_utils
from keras.callbacks import Callback,EarlyStopping
import numpy

# binary encode numbers
num_digits = 10 
# 四種類型：number/fizz/buzz/fizzbuzz
nb_classes = 4 
# batch_size 每一批次訓練筆數
batch_size = 128

# 設定題目規則
# 將每個十進位數轉換成二制進數組，比如 100 => [ 0,0,0,1,1,0,0,1,0,0] ,共10維。
# 其對應的標籤為：
# [0,0,0,1] => 'Fizz'
# [0,0,1,0] =>'Buzz'
# [0,1,0,0] =>'FizzBuzz'
# [1,0,0,0] =>'其它'共4維


def fb_encode(i):
    if   i % 15 == 0: return [3]
    elif i % 5  == 0: return [2]
    elif i % 3  == 0: return [1]
    else:             return [0]

def bin_encode(i):
    return [i >> d & 1 for d in range(num_digits)]

def fizz_buzz_pred(i, pred):
    return [str(i), "fizz", "buzz", "fizzbuzz"][pred.argmax()]


def fizz_buzz(i):
    if   i % 15 == 0: return "fizzbuzz"
    elif i % 5  == 0: return "buzz"
    elif i % 3  == 0: return "fizz"
    else:             return str(i)

# 劃分訓練集跟測試集
def create_dataset(start, end):
    dataX,dataY = [],[]
    for i in range(start,end):
        dataX.append(bin_encode(i))
        dataY.append(fb_encode(i))
    return numpy.array(dataX),np_utils.to_categorical(numpy.array(dataY), nb_classes)


x_train,y_train = create_dataset(101,1001)
x_test,y_test = create_dataset(1,101)

# %%
#訓練集
x_train.shape
x_train[0]
# Out:
# array([1, 0, 1, 0, 0, 1, 1, 0, 0, 0])

# %%
#測試集
y_train.shape
y_train[0]
# Out:
# array([1., 0., 0., 0.], dtype=float32)

# %%
#建立 keras的Sequential model
model = Sequential()

# 建立dense層，輸入為10個神經元，輸出為1000個神經元
# Activation Function為  relu
model.add(Dense(input_dim=10, units=1000))
model.add(Activation('relu'))

# 建立dense層，輸入為上層的輸出，輸出為4個神經元
# Activation Function為 softmax
model.add(Dense(units=4))
model.add(Activation('softmax'))

#定義模型訓練方式：
#設定loss function
#optimizer 設定優化器
#設定評估模型的方式為 accuracy
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

#設定訓練資料參數
#設定訓言資料與驗證資料比例
#設定epoch訓練週期
model.fit(x_train,y_train,batch_size=20, epochs=100)

#預測準確率
result = model.evaluate(x_test,y_test)
score = model.evaluate(x_train,y_train)
print('\nTrain Acc:', score[1])
result = model.evaluate(x_test,y_test)
print('\nTest Acc:', result[1])
# Out:
# Epoch 1/100
# 45/45 [==============================] - 0s 2ms/step - loss: 1.1850 - accuracy: 0.5233
# Epoch 2/100
# 45/45 [==============================] - 0s 2ms/step - loss: 1.1493 - accuracy: 0.5333
# Epoch 3/100
100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.5594 - accuracy: 0.8467
# Epoch 31/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.5361 - accuracy: 0.8789
# Epoch 32/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.5248 - accuracy: 0.8711
# Epoch 33/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4973 - accuracy: 0.8956
# Epoch 34/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4762 - accuracy: 0.9067
# Epoch 35/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4532 - accuracy: 0.9144
# Epoch 36/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4272 - accuracy: 0.9378
# Epoch 37/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4070 - accuracy: 0.9456
# Epoch 38/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3897 - accuracy: 0.9578
# Epoch 39/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3753 - accuracy: 0.9511
# Epoch 40/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3541 - accuracy: 0.9589
# Epoch 41/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3353 - accuracy: 0.9756
# Epoch 42/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3193 - accuracy: 0.9722
# Epoch 43/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3091 - accuracy: 0.9733
# Epoch 44/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2923 - accuracy: 0.9778
# Epoch 45/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2850 - accuracy: 0.9756
# Epoch 46/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2705 - accuracy: 0.9789
# Epoch 47/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2529 - accuracy: 0.9844
# Epoch 48/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2425 - accuracy: 0.9889
# Epoch 49/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2328 - accuracy: 0.9900
# Epoch 50/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2212 - accuracy: 0.9867
# Epoch 51/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2111 - accuracy: 0.9933
# Epoch 52/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2059 - accuracy: 0.9933
# Epoch 53/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1907 - accuracy: 0.9933
# Epoch 54/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1846 - accuracy: 0.9944
# Epoch 55/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1752 - accuracy: 0.9967
# Epoch 56/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 0.9944
# Epoch 57/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1597 - accuracy: 0.9989
# Epoch 58/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1543 - accuracy: 0.9933
# Epoch 59/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1466 - accuracy: 0.9978
# Epoch 60/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1419 - accuracy: 0.9967
# Epoch 61/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1373 - accuracy: 0.9967
# Epoch 62/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1299 - accuracy: 0.9978
# Epoch 63/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1268 - accuracy: 0.9978
# Epoch 64/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1204 - accuracy: 0.9967
# Epoch 65/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1157 - accuracy: 0.9978
# Epoch 66/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1121 - accuracy: 0.9967
# Epoch 67/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1057 - accuracy: 0.9989
# Epoch 68/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.9989
# Epoch 69/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0995 - accuracy: 0.9978
# Epoch 70/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0950 - accuracy: 0.9978
# Epoch 71/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 0.9989
# Epoch 72/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0893 - accuracy: 0.9989
# Epoch 73/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0886 - accuracy: 0.9989
# Epoch 74/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0817 - accuracy: 1.0000
# Epoch 75/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0781 - accuracy: 1.0000
# Epoch 76/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0751 - accuracy: 0.9989
# Epoch 77/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0721 - accuracy: 1.0000
# Epoch 78/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0723 - accuracy: 0.9978
# Epoch 79/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0686 - accuracy: 0.9989
# Epoch 80/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0651 - accuracy: 1.0000
# Epoch 81/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0649 - accuracy: 0.9989
# Epoch 82/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0618 - accuracy: 1.0000
# Epoch 83/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0583 - accuracy: 1.0000
# Epoch 84/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0571 - accuracy: 1.0000
# Epoch 85/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0540 - accuracy: 1.0000
# Epoch 86/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 1.0000
# Epoch 87/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 88/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0512 - accuracy: 1.0000
# Epoch 89/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 1.0000
# Epoch 90/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0451 - accuracy: 1.0000
# Epoch 91/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 92/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0434 - accuracy: 1.0000
# Epoch 93/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 94/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 95/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 96/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 97/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 98/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 99/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 100/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 1.0000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9900
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 1.0000
#
# Train Acc: 1.0
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9900
#
# Test Acc: 0.9900000095367432

# %%
def fizz_buzz(n): 
    for i in range(1, n+1):
        result = ''
        if i%3 == 0:
            result += 'Fizz'
        if i%5 == 0:
            result += 'Buzz'
        if len(result)>0:
            print(result)
        else:
            print(i)

# %%
fizz_buzz(100)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz
