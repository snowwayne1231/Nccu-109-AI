# %%
#載入套件
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.optimizers import RMSprop
from keras.utils import np_utils
from keras.callbacks import Callback,EarlyStopping
import numpy

# binary encode numbers
num_digits = 10 
# 四種類型：number/fizz/buzz/fizzbuzz
nb_classes = 4 
# batch_size 每一批次訓練筆數
batch_size = 128

# 設定題目規則
# 將每個十進位數轉換成二制進數組，比如 100 => [ 0,0,0,1,1,0,0,1,0,0] ,共10維。
# 其對應的標籤為：
# [0,0,0,1] => 'Fizz'
# [0,0,1,0] =>'Buzz'
# [0,1,0,0] =>'FizzBuzz'
# [1,0,0,0] =>'其它'共4維


def fb_encode(i):
    if   i % 15 == 0: return [3]
    elif i % 5  == 0: return [2]
    elif i % 3  == 0: return [1]
    else:             return [0]

def bin_encode(i):
    return [i >> d & 1 for d in range(num_digits)]

def fizz_buzz_pred(i, pred):
    return [str(i), "fizz", "buzz", "fizzbuzz"][pred.argmax()]


def fizz_buzz(i):
    if   i % 15 == 0: return "fizzbuzz"
    elif i % 5  == 0: return "buzz"
    elif i % 3  == 0: return "fizz"
    else:             return str(i)

# 劃分訓練集跟測試集
def create_dataset(start, end):
    dataX,dataY = [],[]
    for i in range(start,end):
        dataX.append(bin_encode(i))
        dataY.append(fb_encode(i))
    return numpy.array(dataX),np_utils.to_categorical(numpy.array(dataY), nb_classes)


x_train,y_train = create_dataset(101,1001)
x_test,y_test = create_dataset(1,101)

# %%
#訓練集
x_train.shape
x_train[0]
# Out:
# array([1, 0, 1, 0, 0, 1, 1, 0, 0, 0])

# %%
#測試集
y_train.shape
y_train[0]
# Out:
# array([1., 0., 0., 0.], dtype=float32)

# %%
#建立 keras的Sequential model
model = Sequential()

# 建立dense層，輸入為10個神經元，輸出為1000個神經元
# Activation Function為  relu
model.add(Dense(input_dim=10, units=1000))
model.add(Activation('relu'))

# 建立dense層，輸入為上層的輸出，輸出為4個神經元
# Activation Function為 softmax
model.add(Dense(units=4))
model.add(Activation('softmax'))

#定義模型訓練方式：
#設定loss function
#optimizer 設定優化器
#設定評估模型的方式為 accuracy
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

#設定訓練資料參數
#設定訓言資料與驗證資料比例
#設定epoch訓練週期
model.fit(x_train,y_train,batch_size=20, epochs=100)

#預測準確率
result = model.evaluate(x_test,y_test)
score = model.evaluate(x_train,y_train)
print('\nTrain Acc:', score[1])
result = model.evaluate(x_test,y_test)
print('\nTest Acc:', result[1])
# Out:
# Epoch 1/100
# 45/45 [==============================] - 0s 930us/step - loss: 1.2339 - accuracy: 0.4982
# Epoch 2/100
# 45/45 [==============================] - 0s 891us/step - loss: 1.1475 - accuracy: 0.5385
# Epoch 3/100
# 45/45 [==============================] - 0s 1ms/step - loss: 1.1350 - accuracy: 0.5522
# Epoch 4/100
# 45/45 [==============================] - 0s 975us/step - loss: 1.1453 - accuracy: 0.5301
# Epoch 5/100
# 45/45 [==============================] - 0s 934us/step - loss: 1.1202 - accuracy: 0.5350
# Epoch 6/100
# 45/45 [==============================] - 0s 1ms/step - loss: 1.1282 - accuracy: 0.5441
# Epoch 7/100
# 45/45 [==============================] - 0s 904us/step - loss: 1.1079 - accuracy: 0.5347
# Epoch 8/100
# 45/45 [==============================] - 0s 962us/step - loss: 1.1013 - accuracy: 0.5499
# Epoch 9/100
# 45/45 [==============================] - 0s 923us/step - loss: 1.1128 - accuracy: 0.5056
# Epoch 10/100
# 45/45 [==============================] - 0s 919us/step - loss: 1.0964 - accuracy: 0.5084
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0005 - accuracy: 0.60 - 0s 1ms/step - loss: 1.0425 - accuracy: 0.5489
# Epoch 12/100
# 45/45 [==============================] - 0s 970us/step - loss: 1.0188 - accuracy: 0.5398
# Epoch 13/100
# 45/45 [==============================] - 0s 979us/step - loss: 1.0214 - accuracy: 0.5367
# Epoch 14/100
# 45/45 [==============================] - 0s 1ms/step - loss: 1.0068 - accuracy: 0.5368
# Epoch 15/100
# 45/45 [==============================] - 0s 951us/step - loss: 0.9511 - accuracy: 0.5506
# Epoch 16/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.9058 - accuracy: 0.5851
# Epoch 17/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.9032 - accuracy: 0.5766
# Epoch 18/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.8909 - accuracy: 0.5825
# Epoch 19/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.8837 - accuracy: 0.5987
# Epoch 20/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.8131 - accuracy: 0.6386
# Epoch 21/100
# 45/45 [==============================] - 0s 953us/step - loss: 0.7920 - accuracy: 0.6442
# Epoch 22/100
# 45/45 [==============================] - 0s 955us/step - loss: 0.7749 - accuracy: 0.6837
# Epoch 23/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.7490 - accuracy: 0.7335
# Epoch 24/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.7369 - accuracy: 0.7053
# Epoch 25/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.6853 - accuracy: 0.7291
# Epoch 26/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.6524 - accuracy: 0.7803
# Epoch 27/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.6310 - accuracy: 0.7998
# Epoch 28/100
# 45/45 [==============================] - 0s 937us/step - loss: 0.5990 - accuracy: 0.8122
# Epoch 29/100
# 45/45 [==============================] - 0s 861us/step - loss: 0.5929 - accuracy: 0.8589
# Epoch 30/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5470 - accuracy: 0.8457
# Epoch 31/100
# 45/45 [==============================] - 0s 926us/step - loss: 0.5041 - accuracy: 0.8863
# Epoch 32/100
# 45/45 [==============================] - 0s 912us/step - loss: 0.5052 - accuracy: 0.8962
# Epoch 33/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.4686 - accuracy: 0.9119
# Epoch 34/100
# 45/45 [==============================] - 0s 980us/step - loss: 0.4601 - accuracy: 0.9457
# Epoch 35/100
# 45/45 [==============================] - 0s 995us/step - loss: 0.4395 - accuracy: 0.9322
# Epoch 36/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.4229 - accuracy: 0.9422
# Epoch 37/100
# 45/45 [==============================] - 0s 1000us/step - loss: 0.4061 - accuracy: 0.9569
# Epoch 38/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.3833 - accuracy: 0.9396
# Epoch 39/100
# 45/45 [==============================] - 0s 959us/step - loss: 0.3525 - accuracy: 0.9530
# Epoch 40/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.3440 - accuracy: 0.9673
# Epoch 41/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.3283 - accuracy: 0.9591
# Epoch 42/100
# 45/45 [==============================] - ETA: 0s - loss: 0.3045 - accuracy: 1.00 - 0s 957us/step - loss: 0.3178 - accuracy: 0.9736
# Epoch 43/100
# 45/45 [==============================] - 0s 935us/step - loss: 0.3083 - accuracy: 0.9764
# Epoch 44/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.2836 - accuracy: 0.9655
# Epoch 45/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.2798 - accuracy: 0.9821
# Epoch 46/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.2496 - accuracy: 0.9791
# Epoch 47/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.2363 - accuracy: 0.9752
# Epoch 48/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.2229 - accuracy: 0.9900
# Epoch 49/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0
100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0641 - accuracy: 1.0000
# Epoch 81/100
# 45/45 [==============================] - 0s 974us/step - loss: 0.0551 - accuracy: 0.9997
# Epoch 82/100
# 45/45 [==============================] - 0s 895us/step - loss: 0.0534 - accuracy: 0.9996
# Epoch 83/100
# 45/45 [==============================] - 0s 952us/step - loss: 0.0514 - accuracy: 0.9998
# Epoch 84/100
# 45/45 [==============================] - 0s 903us/step - loss: 0.0543 - accuracy: 1.0000
# Epoch 85/100
# 45/45 [==============================] - 0s 929us/step - loss: 0.0473 - accuracy: 0.9996
# Epoch 86/100
# 45/45 [==============================] - 0s 906us/step - loss: 0.0466 - accuracy: 0.9996
# Epoch 87/100
# 45/45 [==============================] - 0s 922us/step - loss: 0.0469 - accuracy: 1.0000
# Epoch 88/100
# 45/45 [==============================] - 0s 951us/step - loss: 0.0456 - accuracy: 0.9979
# Epoch 89/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 1.00 - 0s 932us/step - loss: 0.0430 - accuracy: 1.0000
# Epoch 90/100
# 45/45 [==============================] - 0s 951us/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 91/100
# 45/45 [==============================] - 0s 960us/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 92/100
# 45/45 [==============================] - 0s 969us/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 93/100
# 45/45 [==============================] - 0s 928us/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 94/100
# 45/45 [==============================] - 0s 937us/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 95/100
# 45/45 [==============================] - 0s 977us/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 96/100
# 45/45 [==============================] - 0s 928us/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 97/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 98/100
# 45/45 [==============================] - 0s 952us/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 99/100
# 45/45 [==============================] - 0s 939us/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 100/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0300 - accuracy: 1.0000
# 4/4 [==============================] - 0s 998us/step - loss: 0.0426 - accuracy: 1.0000
# 29/29 [==============================] - 0s 756us/step - loss: 0.0287 - accuracy: 1.0000
#
# Train Acc: 1.0
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0426 - accuracy: 1.0000
#
# Test Acc: 1.0

# %%
def fizz_buzz(n): 
    for i in range(1, n+1):
        result = ''
        if i%3 == 0:
            result += 'Fizz'
        if i%5 == 0:
            result += 'Buzz'
        if len(result)>0:
            print(result)
        else:
            print(i)

# %%
fizz_buzz(100)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz
